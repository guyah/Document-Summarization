# %%
import xml.etree.ElementTree as ET
import os
import numpy as np
import re
import copy
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import glob
files = glob.glob("fulltext/*.xml")

for f in files:
    print(f)
    full_path = f
    f = open(full_path, 'r')
    linelist = f.readlines()
    f.close

    # Re-open file here
    f2 = open(full_path, 'w')
    for line in linelist:
        line = line.replace("\"id=c0\"", "")
        line = line.replace("\"id=c1\"", "")
        line = line.replace("\"id=c2\"", "")
        line = line.replace("\"id=c3\"", "")
        line = line.replace("\"id=c4\"", "")
        line = line.replace("\"id=c5\"", "")
        line = line.replace("\"id=c6\"", "")
        line = line.replace("\"id=c7\"", "")
        line = line.replace("\"id=c8\"", "")
        line = line.replace("\"id=c9\"", "")
        line = line.replace("\"id=c10\"", "")
        line = line.replace("\"id=c11\"", "")
        line = line.replace("\"id=c12\"", "")
        line = line.replace("\"id=c13\"", "")
        line = line.replace("\"id=c14\"", "")
        line = line.replace("\"id=c15\"", "")
        line = line.replace("\"id=c16\"", "")
        line = line.replace("\"id=c17\"", "")
        line = line.replace("\"id=c18\"", "")
        line = line.replace("\"id=c19\"", "")
        line = line.replace("\"id=c20\"", "")
        line = line.replace("\"id=c21\"", "")
        line = line.replace("\"id=c22\"", "")
        line = line.replace("\"id=c23\"", "")
        line = line.replace("\"id=c24\"", "")
        line = line.replace("\"id=c25\"", "")
        line = line.replace("\"id=c26\"", "")
        line = line.replace("\"id=c27\"", "")
        line = line.replace("\"id=c28\"", "")
        line = line.replace("\"id=c29\"", "")
        line = line.replace("\"id=c30\"", "")
        f2.write(line)
    f2.close()
# Out:
# fulltext/06_364.xml
# fulltext/09_622.xml
# fulltext/07_965.xml
# fulltext/08_316.xml
# fulltext/09_202.xml
# fulltext/08_1387.xml
# fulltext/07_1705.xml
# fulltext/07_90.xml
# fulltext/07_33.xml
# fulltext/09_709.xml
# fulltext/09_1112.xml
# fulltext/06_906.xml
# fulltext/08_265.xml
# fulltext/08_1025.xml
# fulltext/09_1134.xml
# fulltext/08_768.xml
# fulltext/07_1348.xml
# fulltext/08_1922.xml
# fulltext/09_73.xml
# fulltext/06_489.xml
# fulltext/08_1490.xml
# fulltext/06_1478.xml
# fulltext/09_546.xml
# fulltext/06_1174.xml
# fulltext/06_1006.xml
# fulltext/08_1903.xml
# fulltext/06_195.xml
# fulltext/08_12.xml
# fulltext/09_701.xml
# fulltext/09_498.xml
# fulltext/08_159.xml
# fulltext/06_1804.xml
# fulltext/08_498.xml
# fulltext/08_1405.xml
# fulltext/07_1412.xml
# fulltext/09_1016.xml
# fulltext/07_1375.xml
# fulltext/08_970.xml
# fulltext/09_789.xml
# fulltext/07_1080.xml
# fulltext/08_16.xml
# fulltext/09_673.xml
# fulltext/07_922.xml
# fulltext/07_834.xml
# ...
